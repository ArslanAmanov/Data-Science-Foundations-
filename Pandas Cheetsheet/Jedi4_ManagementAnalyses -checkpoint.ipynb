# %%
import pandas as pd 
pd.options.display.float_format = '{:,}'.format 

pd.set_option('display.max_columns', None) 
pd.set_option('display.max_rows', None) 

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

from nltk.tokenize import regexp_tokenize
from nltk.util import ngrams

import numpy as np

import re
      
def reset(df):
    cols = df.columns
    return df.reset_index()[cols]

def word_tokenize(txt):
    return regexp_tokenize(txt, "[\w']+")

print('Jedi!')
# Out:
# Jedi!

# %%
df2 = pd.read_csv('Hospital.csv') 
df2.head() 
df2.shape
# Out:
#    No.                   Name (Thai)                      Name (Eng)  \
# 0    1              โรงพยาบาลกรุงเทพ        BANGKOK GENERAL HOSPITAL
# 1    2     โรงพยาบาลกรุงเทพคริสเตียน      BANGKOK CHRISTIAN HOSPITAL
# 2    3         โรงพยาบาลกล้วยน้ำไท 1         KLUAYNAMTHAI 1 HOSPITAL
# 3    4         โรงพยาบาลกล้วยน้ำไท 2          KLUAYNAMTHAI2 HOSPITAL
# 4    5  โรงพยาบาลเกษมราษฎร์ รามคำแหง  KASEMRAD RAMKHAMHAENG HOSPITAL
#
#   TPA Hospital Code PLT Hospital Code Contract  \
# 0      PVR201600909          41000039  TPA/PLT
# 1      PVR201600910          41000023  TPA/PLT
# 2      PVR201600913          41000008  TPA/PLT
# 3      PVR201600914          41000239  TPA/PLT
# 4      PVR201800117          41000893  TPA/PLT
#
#                                    Website Telephone Number  \
# 0           http://www.bangkokhospital.com      02 310 3000
# 1  http://www.bangkokchristianhospital.org      0-2625-9000
# 2              http://www.kluaynamthai.com      0-2769-2000
# 3              http://www.kluaynamthai.com      02 399 4259
# 4                http://www.kasemrad.co.th      02 339 0000
#
#            Address 1          Address 2 Address 3       Province Province ENG  \
# 0  2 ซอยศูนย์วิจัย 7  ถ.เพชรบุรีตัดใหม่  ห้วยขวาง  กรุงเทพมหานคร      Bangkok
# 1                124             ถ.สีลม    บางรัก  กรุงเทพมหานคร      Bangkok
# 2  80 ซ.โรงพยาบาล 2          ถ.พระราม 4   คลองเตย  กรุงเทพมหานคร      Bangkok
# 3   27 ซ.สุขุมวิท 68                  -     บางนา  กรุงเทพมหานคร      Bangkok
# 4               99/9         ถ.รามคำแหง  สะพานสูง  กรุงเทพมหานคร      Bangkok
#
#                  Region  Postal Code Hospital type     Type Specialty  \
# 0  Bangkok Metropolitan        10320      Hospital  Private   General
# 1  Bangkok Metropolitan        10500      Hospital  Private   General
# 2  Bangkok Metropolitan        10110      Hospital  Private   General
# 3  Bangkok Metropolitan        10260      Hospital  Private   General
# 4  Bangkok Metropolitan        10240      Hospital  Private   General
#
#    Condition Remark  Unnamed: 20  Unnamed: 21  Unnamed: 22  Unnamed: 23  \
# 0  OPD + IPD    NaN          nan          nan          nan          nan
# 1  OPD + IPD    NaN          nan          nan          nan          nan
# 2  OPD + IPD    NaN          nan          nan          nan          nan
# 3  OPD + IPD    NaN          nan          nan          nan          nan
# 4  OPD + IPD    NaN          nan          nan          nan          nan
#
#    Unnamed: 24  Unnamed: 25  Unnamed: 26  Unnamed: 27
# 0          nan          nan          nan          nan
# 1          nan          nan          nan          nan
# 2          nan          nan          nan          nan
# 3          nan          nan          nan          nan
# 4          nan          nan          nan          nan
# (518, 28)

# %% [markdown]
# # Statistical Learning
# Statistical learning refers to a vast set of tools for understanding data. These tools can be classified as supervised or unsupervised. Broadly speaking, supervised statistical learning involves building a statistical model for predicting, or estimating, an output based on one or more inputs. Problems of this nature occur in fields as diverse as business,medicine,astrophysics,and public policy. With unsupervised statistical learning, there are inputs but no supervising output; nevertheless, we can learn relationships and structure from such data. Unsupervised learning problems can also be found in a wide range of fields....

# %% [markdown]
# # Wage data

# %%
# ! pip install ISLP

# %%
from ISLP import load_data
# # In this application which we refer to as the "Wage" data set througout.. 
# # we examine a number of factors that relate to wages for a group of men from the Atlantic region of the US. 
# # In particular we wish to understand the association between an employee's age and education, as well as the 
# # calendar year, on his wage. 

# # The data set contains 3000 observations on 11 variables.

wage = load_data('Wage')
wage.columns
# Out:
# Index(['year', 'age', 'maritl', 'race', 'education', 'region', 'jobclass',
#        'health', 'health_ins', 'logwage', 'wage'],
#       dtype='object')

# %%
wage.shape
# Out:
# (3000, 11)

# %%
wage.describe()
# Out:
#               year          age      logwage         wage
# count  3000.000000  3000.000000  3000.000000  3000.000000
# mean   2005.791000    42.414667     4.653905   111.703608
# std       2.026167    11.542406     0.351753    41.728595
# min    2003.000000    18.000000     3.000000    20.085537
# 25%    2004.000000    33.750000     4.447158    85.383940
# 50%    2006.000000    42.000000     4.653213   104.921507
# 75%    2008.000000    51.000000     4.857332   128.680488
# max    2009.000000    80.000000     5.763128   318.342430

# %%
from IPython.display import Image 
Image(filename='wagefigure.png', width=800, height=800)

# %%
wage.head()
# Out:
#    year  age            maritl      race        education              region  \
# 0  2006   18  1. Never Married  1. White     1. < HS Grad  2. Middle Atlantic
# 1  2004   24  1. Never Married  1. White  4. College Grad  2. Middle Atlantic
# 2  2003   45        2. Married  1. White  3. Some College  2. Middle Atlantic
# 3  2003   43        2. Married  3. Asian  4. College Grad  2. Middle Atlantic
# 4  2005   50       4. Divorced  1. White       2. HS Grad  2. Middle Atlantic
#
#          jobclass          health health_ins   logwage        wage
# 0   1. Industrial       1. <=Good      2. No  4.318063   75.043154
# 1  2. Information  2. >=Very Good      2. No  4.255273   70.476020
# 2   1. Industrial       1. <=Good     1. Yes  4.875061  130.982177
# 3  2. Information  2. >=Very Good     1. Yes  5.041393  154.685293
# 4  2. Information       1. <=Good     1. Yes  4.318063   75.043154

# %%
import seaborn as sns
import matplotlib.pyplot as plt 
sns.pairplot(wage, kind='reg')

# %% [markdown]
# Given an employee's age, we can use this curve to predict his wage.However,it is also clear that there is a significant amount of variablity associated with this average value,and so age alone is unlikely to provide an accurate prediction of a particular man's wage.

# %%
# We also have information regarding each employee's education level and the year in which the wage was earned. 
# The center and right-hand panels of Fig 1.1 which display wage as a function of both year and education,indicate
# that both of these factors are associated with wage. 
# Wages increase by approximately $10,000 in a rougly linear fashion between 2003 and 2009. 
# though this rise is very slight relative to the variablity in the data. 
# Wages are also typically greater for individuals with higher education levels: men witht the lowest education level(1) 
# tend to have substantially lower wages than those with the highest education level(5). 
# Clearly, the most accurate predictions of a given man's wage will be obtained by combining his age,his education and the year. 
# Ideally, we should predict wage in a way that accounts for the non-linear relationship between age and wage.

# %% [markdown]
# # Stock Market Data

# %%
from IPython.display import Image 
Image(filename='stockmarket_data.png', width=800, height=800)

# %% [markdown]
# The Wage data involves predicting a continous or quantitative output value. This often refers to as a regression problem. However, in certain cases we may instead wish to predict a non-numerical value-that is a categorical or qualitative output. For example, we may wish to examine a stock market data set that contains the daily movements in the Standard & Poor's 500 stock index over a 5-year period between 2001-2005. The goal is to predict whether the index will increase or decrease on a given day, using the 5 day's percentage changes in the index. Here's the statistical learning problem does not involve predicting a numerical value. Instead, it involves predicting whether a given day's stock market performance will fall into the Up bucket or the Down bucket. This is known as a classification problem.. A model that could accurately predict the direction in which the market will move would be very useful...
